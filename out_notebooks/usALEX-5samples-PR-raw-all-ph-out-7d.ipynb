# %% [markdown]
# # usALEX-5samples - Template
#
# > *This notebook is a template that is executed by [usALEX-Batch](usALEX-Batch.ipynb) in order to fit E and S values of the FRET population for all the 5 smFRET samples.*
# >
# > *This notebook reads the environment variable NB_DATA_FILE to select which file to process.*

# %% [markdown]
# ## Load software and filenames definitions

# %%
# %run load_fretbursts.py --nogui
# Out:
#  - Optimized (cython) burst search loaded.
#  - Optimized (cython) photon counting loaded.
#
# FRETBursts revision:
#  2014-08-25 63c9f7e Only lists are converted to arrays in fretmath.py, in order to preserve pandas objects.

# %%
# %cd $NOTEBOOK_DIR
# Out:
# C:\Data\Antonio\software\src\multispot_paper

# %%
data_dir = os.path.abspath(NOTEBOOK_DIR+'/data') + '/'
assert os.path.exists(data_dir), "Path '%s' does not exist." % data_dir

# %%
## Files
f7 = "2012-11-26/006_dsDNA_7d_green100u_red40u.sm"
f12 = "2012-11-26/007_dsDNA_12d_3nM_green100u_red40u.sm"
f17 = "2012-11-26/004_dsDNA_17d_green100u_red40u.sm"
f22 = "2012-11-26/008_dsDNA_22d_500pM_green100u_red40u.sm"
f27 = "2012-11-26/005_dsDNA_27d_green100u_red40u.sm"

f7, f12, f17, f22, f27 = [data_dir + f[:-2]+'hdf5' for f in [f7, f12, f17, f22, f27]]

f_dict = {'7d': f7, '12d': f12, '17d': f17, '22d': f22, '27d': f27}

# %%
f_dict
# Out:
# {'12d': 'C:\\Data\\Antonio\\software\\src\\multispot_paper\\data/2012-11-26/007_dsDNA_12d_3nM_green100u_red40u.hdf5',
#  '17d': 'C:\\Data\\Antonio\\software\\src\\multispot_paper\\data/2012-11-26/004_dsDNA_17d_green100u_red40u.hdf5',
#  '22d': 'C:\\Data\\Antonio\\software\\src\\multispot_paper\\data/2012-11-26/008_dsDNA_22d_500pM_green100u_red40u.hdf5',
#  '27d': 'C:\\Data\\Antonio\\software\\src\\multispot_paper\\data/2012-11-26/005_dsDNA_27d_green100u_red40u.hdf5',
#  '7d': 'C:\\Data\\Antonio\\software\\src\\multispot_paper\\data/2012-11-26/006_dsDNA_7d_green100u_red40u.hdf5'}

# %%
data_id = os.environ['NB_DATA_FILE']
data_id
# Out:
# '7d'

# %%
# data_id = '7d'

# %% [markdown]
# ## Data load

# %% [markdown]
# Initial loading of the data:

# %%
d = loader.hdf5(fname=f_dict[data_id])

# %% [markdown]
# ## Laser alternation selection
#
# At this point we have only the timestamps and the detector numbers:

# %%
d.ph_times_t, d.det_t
# Out:
# (array([       9160,       41823,       50082, ..., 47999600055,
#         47999607904, 47999679104], dtype=int64),
#  array([1, 1, 1, ..., 1, 1, 1], dtype=uint8))

# %% [markdown]
# We need to define some parameters: donor and acceptor ch, excitation period and donor and acceptor excitiations:

# %%
d.add(det_donor_accept=(0, 1), alex_period=4000, D_ON=(2850, 580), A_ON=(900, 2580))

# %% [markdown]
# We should check if everithing is OK with an alternation histogram:

# %%
plot_alternation_hist(d)

# %% [markdown]
# If the plot looks good we can apply the parameters with:

# %%
loader.usalex_apply_period(d)
# Out:
# #donor: 459745  #acceptor: 1447961
# 2012-11-26_006_dsDNA_7d_green100u_red40u G1.000

# %% [markdown]
# ##Measurements infos

# %% [markdown]
# All the measurement data is in the `d` variable. We can print it:

# %%
d
# Out:
# 2012-11-26_006_dsDNA_7d_green100u_red40u G1.000

# %% [markdown]
# Or check the **measurements duration**:

# %%
d.time_max()
# Out:
# 599.99598879999996

# %% [markdown]
# ##Compute background

# %% [markdown]
# Compute the background using automatic threshold:

# %%
d.calc_bg(bg.exp_fit, time_s=60, tail_min_us='auto', F_bg=1.7)
# Out:
#  - Calculating BG rates ...
# [DONE]

# %%
dplot(d, timetrace_bg)
# Out:
# (<matplotlib.axes.AxesSubplot at 0x1977b630>, None)

# %%
d.rate_m, d.rate_dd, d.rate_ad, d.rate_aa
# Out:
# ([2403.0762016420258],
#  [448.36485539224697],
#  [1074.063011778215],
#  [825.92110166787495])

# %% [markdown]
# #Burst search and burst selection

# %%
d.burst_search_t(L=10, m=10, F=7, ph_sel=Ph_sel('all'))
# Out:
#  - Performing burst search (verbose=False) ...
# [DONE]
#  - Calculating burst periods ...
# [DONE]
#  - Counting D and A ph and calculating FRET ...
#    - Applying background correction.
#    - Applying leakage correction.
#    - Applying direct excitation correction.
#    [DONE Counting D/A]

# %%
assert d.dir_ex == 0
assert d.leakage == 0

# %%
print d.ph_sel
dplot(d, hist_fret);
# Out:
# Ph_sel(Dex='DAem', Aex='DAem')

# %%
# if data_id in ['7d', '27d']:
#     ds = Sel(d, select_bursts.size, th1=20)
# else:
#     ds = Sel(d, select_bursts.size, th1=30)

# %%
ds = Sel(d, select_bursts.size, add_naa=False, th1=30)

# %%
n_bursts_all = ds.num_bursts()[0]

# %%
def select_and_plot_ES(fret_sel, do_sel):
    ds_fret= Sel(ds, select_bursts.ES, **fret_sel)
    ds_do = Sel(ds, select_bursts.ES, **do_sel)
    bpl.plot_ES_selection(ax, **fret_sel)
    bpl.plot_ES_selection(ax, **do_sel)    
    return ds_fret, ds_do

# %%
ax, _ = dplot(ds, hist2d_alex, S_max_norm=2, scatter_alpha=0.1)

if data_id == '7d':
    fret_sel = dict(E1=0.60, E2=1.2, S1=0.2, S2=0.9, rect=False)
    do_sel = dict(E1=-0.2, E2=0.5, S1=0.8, S2=2, rect=True)    
    ds_fret, ds_do = select_and_plot_ES(fret_sel, do_sel)
    
elif data_id == '12d':
    fret_sel = dict(E1=0.30,E2=1.2,S1=0.131,S2=0.9, rect=False)
    do_sel = dict(E1=-0.4, E2=0.4, S1=0.8, S2=2, rect=False)
    ds_fret, ds_do = select_and_plot_ES(fret_sel, do_sel)

elif data_id == '17d':
    fret_sel = dict(E1=0.01, E2=0.98, S1=0.14, S2=0.88, rect=False)
    do_sel = dict(E1=-0.4, E2=0.4, S1=0.80, S2=2, rect=False)
    ds_fret, ds_do = select_and_plot_ES(fret_sel, do_sel)

elif data_id == '22d':
    fret_sel = dict(E1=-0.16, E2=0.6, S1=0.2, S2=0.80, rect=False)
    do_sel = dict(E1=-0.2, E2=0.4, S1=0.85, S2=2, rect=True)
    ds_fret, ds_do = select_and_plot_ES(fret_sel, do_sel)    

elif data_id == '27d':
    fret_sel = dict(E1=-0.1, E2=0.5, S1=0.2, S2=0.82, rect=False)
    do_sel = dict(E1=-0.2, E2=0.4, S1=0.88, S2=2, rect=True)
    ds_fret, ds_do = select_and_plot_ES(fret_sel, do_sel)

# %%
n_bursts_do = ds_do.num_bursts()[0]
n_bursts_fret = ds_fret.num_bursts()[0]

n_bursts_do, n_bursts_fret
# Out:
# (724, 600)

# %%
d_only_frac = 1.*n_bursts_do/(n_bursts_do + n_bursts_fret)
print 'D-only fraction:', d_only_frac
# Out:
# D-only fraction: 0.546827794562

# %%
dplot(ds_fret, hist2d_alex, scatter_alpha=0.1);

# %%
dplot(ds_do, hist2d_alex, S_max_norm=2, scatter=False);

# %%
bandwidth = 0.03

E_range_do = (-0.1, 0.15)
E_ax = np.r_[-0.2:0.3:0.0002]

E_pr_do_kde = bext.fit_E_kde_peak(ds_do, bandwidth=bandwidth, E_range=E_range_do, E_ax=E_ax, weights='size')[0]

# %%
dplot(ds_do, hist_fret_kde, bins=np.r_[-0.4:1.2:bandwidth], bandwidth=bandwidth, weights='size');
plt.xlim(-0.3, 0.4)
plt.axvline(E_pr_do_kde, color='r', ls='--')
print ds.ph_sel, E_pr_do_kde*100
# Out:
# Ph_sel(Dex='DAem', Aex='DAem') 9.5

# %%
nt_th1 = 50

# %%
dplot(ds_fret, hist_size, which='nd+na')
xlim(-0, 250)
plt.axvline(nt_th1)
# Out:
# C:\Users\laser2002j\Anaconda\lib\site-packages\matplotlib\transforms.py:644: RuntimeWarning: invalid value encountered in sign
#   dx0 = np.sign(vertices[:, 0] - x0)
# C:\Users\laser2002j\Anaconda\lib\site-packages\matplotlib\transforms.py:645: RuntimeWarning: invalid value encountered in sign
#   dy0 = np.sign(vertices[:, 1] - y0)
# C:\Users\laser2002j\Anaconda\lib\site-packages\matplotlib\transforms.py:646: RuntimeWarning: invalid value encountered in sign
#   dx1 = np.sign(vertices[:, 0] - x1)
# C:\Users\laser2002j\Anaconda\lib\site-packages\matplotlib\transforms.py:647: RuntimeWarning: invalid value encountered in sign
#   dy1 = np.sign(vertices[:, 1] - y1)

# %%
Th_nt = np.arange(35, 120)
nt_th = np.zeros(Th_nt.size)
for i, th in enumerate(Th_nt):
    ds_nt = Sel(ds_fret, select_bursts.size, th1=th)
    nt_th[i] = (ds_nt.nd[0]  + ds_nt.na[0]).mean() - th

# %%
plt.figure()
plot(Th_nt, nt_th)
plt.axvline(Th_nt[np.where(Th_nt == nt_th1)])

# %%
nt_mean = nt_th[np.where(Th_nt == nt_th1)][0]
nt_mean
# Out:
# 22.375124958435563

# %% [markdown]
# #Fret fit

# %% [markdown]
# Max position of the Kernel Density Estimation (KDE):

# %%
bandwidth = 0.03

E_pr_fret_kde = bext.fit_E_kde_peak(ds_fret, bandwidth=bandwidth, weights='size')[0]
E_pr_fret_kde
# Out:
# 0.9338000000000326

# %%
dplot(ds_fret, hist_fret_kde, weights='size', bins=np.r_[-0.2:1.2:bandwidth], bandwidth=bandwidth);
plt.axvline(E_pr_fret_kde, ls='--', color='r')
print ds_fret.ph_sel, E_pr_fret_kde
# Out:
# Ph_sel(Dex='DAem', Aex='DAem') 0.9338

# %% [markdown]
# Weighted mean of $E$ of each burst:

# %%
ds_fret.fit_E_m(weights='size')
# Out:
# array([ 0.91185903])

# %% [markdown]
# Gaussian fit (no weights):

# %%
ds_fret.fit_E_generic(fit_fun=bl.gaussian_fit_hist, bins=np.r_[-0.1:1.1:0.005], weights=None)
# Out:
# array([ 0.93148092])

# %% [markdown]
# Gaussian fit (using burst size as weights):

# %%
ds_fret.fit_E_generic(fit_fun=bl.gaussian_fit_hist, bins=np.r_[-0.1:1.1:0.005], weights='size')
# Out:
# array([ 0.9303847])

# %%
dplot(ds_fret, hist_fret, weights='size', show_fit=True)
# Out:
# (<matplotlib.axes.AxesSubplot at 0x1a55f9b0>, None)

# %%
E_fit = list(ds_fret.fit_E_res[0])
E_fit
# Out:
# [0.93038469715939287, 0.055971493954198578]

# %% [markdown]
# # Stoichiometry fit

# %%
weights_name = 'size'
weights = bl.fret_fit.get_weights(ds_fret.nd[0], ds_fret.na[0], weights=weights_name, gamma=1)
S = ds_fret.S[0]

# %% [markdown]
# As a comparison, let's fit of the histogram (curve-fit):

# %%
S_fit = bl.gaussian_fit_hist(S, mu0=0.5, sigma0=0.1, bins=np.r_[-0.1:1.1:0.005], weights=weights)
S_fit
# Out:
# (0.56321448475173486, 0.091254848293777308)

# %% [markdown]
# The Maximum likelihood fit for a Gaussian population is the mean:

# %%
S_fit = (S.mean(), S.std())
S_fit
# Out:
# (0.56198472231156393, 0.10053926991096998)

# %% [markdown]
# Computing the weighted mean and weighted standard deviation we get:

# %%
S_mean = np.dot(weights, S)/weights.sum()
S_std_dev = np.sqrt(
        np.dot(weights, (S - S_mean)**2)/weights.sum())
S_fit = [S_mean, S_std_dev]
S_fit
# Out:
# [0.56377576289691234, 0.095691879054050813]

# %%
dplot(ds_fret, hist_S, normed=True, weights=weights_name)
x = np.arange(-0.1, 1.1, 0.005)
plot(x, bpl.normpdf(x, *S_fit), 'k')

# %% [markdown]
# # Save data to file

# %%
# %cd $NOTEBOOK_DIR
# Out:
# C:\Data\Antonio\software\src\multispot_paper

# %%
E_pr_fret, E_pr_fret_sig  = [E_fit[0], E_fit[1]/np.sqrt(ds_fret.num_bursts()[0])]
S_pr_fret, S_pr_fret_sig  = [S_fit[0], S_fit[1]/np.sqrt(ds_fret.num_bursts()[0])]

sample = data_id

# %% [markdown]
# The following string contains the list of variables to be saved. When saving, the order of the variables is preserved.

# %%
variables = ('sample n_bursts_all n_bursts_do n_bursts_fret '
             'E_pr_fret E_pr_fret_sig S_pr_fret S_pr_fret_sig '
             'E_pr_do_kde nt_mean E_pr_fret_kde\n')

# %% [markdown]
# This is just a trick to format the different variables:

# %%
var_dict = {name: eval(name) for name in variables.split()}
var_fmt = ' '.join(['{%s}' % name for name in variables.split()]) + '\n'
data_str = var_fmt.format(**var_dict)

# %%
data_str = var_fmt.format(**var_dict)

# %%
print variables
print data_str
# Out:
# sample n_bursts_all n_bursts_do n_bursts_fret E_pr_fret E_pr_fret_sig S_pr_fret S_pr_fret_sig E_pr_do_kde nt_mean E_pr_fret_kde
#
# 7d 1370 724 600 0.930384697159 0.00228502667215 0.563775762897 0.00390660460351 0.095 22.3751249584 0.9338

# %%
# NOTE: The file name should be the notebook name but with .txt extension
with open('results/usALEX-5samples-PR-raw-all-ph.txt', 'a') as f:
    f.seek(0, 2)
    if f.tell() == 0:
        f.write(variables)
    f.write(data_str)
