# %% [markdown]
# **Executed:** Sun Jun  5 20:59:46 2016
#
# **Duration:** 5 seconds.

# %% [markdown]
# # Figure - usALEX 5 dsDNA samples FRET

# %%
from __future__ import division
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from cycler import cycler
# %matplotlib inline
# %config InlineBackend.figure_format='retina'  # for hi-dpi displays
sns.set_style('whitegrid')

palette = ('Paired', 10)
sns.palplot(sns.color_palette(*palette))
sns.set_palette(*palette)

# %% [markdown]
# ## Load Data

# %%
data_file = 'results/usALEX-5samples-E-all-methods.txt'

# %%
E = pd.read_csv(data_file, index_col=0)
E.round(2)
# Out:
#         E KDE  E Gauss  PR KDE  PR Gauss  SNA Epr mean  SNA Epr max
# sample
# 7d      92.90    92.43   92.87     92.23          89.8         93.7
# 12d     73.98    72.70   72.77     72.56          70.5         71.5
# 17d     42.68    42.26   43.14     41.98          40.0         37.9
# 22d     17.74    18.11   17.62     18.25          17.0         14.7
# 27d      8.26     8.40    7.81      7.85           7.2          5.3

# %%
E.plot.bar(table=np.round(E, 2).T)
plt.ylabel('FRET (%)')
plt.gca().xaxis.set_visible(False)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., frameon=True);
plt.legend(frameon=True);
plt.savefig('figures/5dsDNA FRET usALEX.png', dpi=300, bbox_inches='tight')
